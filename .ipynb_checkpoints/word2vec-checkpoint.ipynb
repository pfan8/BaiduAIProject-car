# %%
import numpy as np
import pandas as pd
from gensim.models import Word2Vec
from gensim.models import FastText
from gensim.models.word2vec import LineSentence
import logging
from utils.utils import * # 自己的工具类

# %% [markdown]
# ## 加载Vocab

# %%
merger_data_path = 'data/merged_train_test_seg_data.csv'
merged_df = pd.read_csv(merger_data_path, header=None)
print('词典数量：{}'.format(len(merged_df)))
merged_df.head()
# Out:
# 词典数量：102871
#                                                    0
# 0  方向机 重 助力泵 方向机 都 换 新 都 换 助力泵 方向机 换 方向机 带 助力 重 这...
# 1  奔驰 ML500 排气凸轮轴 调节 错误 有没有 电脑 检测 故障 代码 有发 一下 发动机...
# 2  2010 款 宝马 X12011 年 出厂 20 排量 通用 6L45 变速箱 原地 换挡 ...
# 3  30V6 发动机号 位置 照片 最好 右侧 排气管 上方 缸体 上 靠近 变速箱 是不是 号...
# 4  2012 款 奔驰 c180 维修保养 动力 值得 拥有 家庭 用车 入手 维修保养 费用 ...

# %%
# 生成gensim训练需要的list，并保存
w2v_data = merged_df[0].apply(lambda x : x.split(' '))
w2v_data = w2v_data.to_list()
print('词典数量：{}'.format(len(w2v_data)))
save_file(w2v_data, 'output/w2v_data')
# Out:
# 词典数量：102871

# %% [markdown]
# ## 2. 训练模型

# %%
# 引入日志配置
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

line_gen = LineSentence(merger_data_path) # generator，节省内存
model = Word2Vec(line_gen, size=300, window=5, min_count=5, workers=8)
model.save("word2vec.model")
# Out:
# 2019-11-23 18:33:10,295 : INFO : collecting all words and their counts
# 2019-11-23 18:33:10,297 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2019-11-23 18:33:10,546 : INFO : PROGRESS: at sentence #10000, processed 932051 words, keeping 37237 word types
# 2019-11-23 18:33:10,799 : INFO : PROGRESS: at sentence #20000, processed 1877470 words, keeping 54830 word types
# 2019-11-23 18:33:11,042 : INFO : PROGRESS: at sentence #30000, processed 2811696 words, keeping 67964 word types
# 2019-11-23 18:33:11,276 : INFO : PROGRESS: at sentence #40000, processed 3718866 words, keeping 79130 word types
# 2019-11-23 18:33:11,525 : INFO : PROGRESS: at sentence #50000, processed 4686367 words, keeping 89249 word types
# 2019-11-23 18:33:11,790 : INFO : PROGRESS: at sentence #60000, processed 5713987 words, keeping 99387 word types
# 2019-11-23 18:33:12,061 : INFO : PROGRESS: at sentence #70000, processed 6764560 words, keeping 109127 word types
# 2019-11-23 18:33:12,313 : INFO : PROGRESS: at sentence #80000, processed 7700093 words, keeping 117393 word types
# 2019-11-23 18:33:12,540 : INFO : PROGRESS: at sentence #90000, processed 8552298 words, keeping 125500 word types
# 2019-11-23 18:33:12,760 : INFO : PROGRESS: at sentence #100000, processed 9396427 words, keeping 132748 word types
# 2019-11-23 18:33:12,829 : INFO : collected 134830 word types from a corpus of 9644394 raw words and 102871 sentences
# 2019-11-23 18:33:12,830 : INFO : Loading a fresh vocabulary
# 2019-11-23 18:33:13,123 : INFO : effective_min_count=5 retains 33167 unique words (24% of original 134830, drops 101663)
# 2019-11-23 18:33:13,123 : INFO : effective_min_count=5 leaves 9492116 word corpus (98% of original 9644394, drops 152278)
# 2019-11-23 18:33:13,214 : INFO : deleting the raw counts dictionary of 134830 items
# 2019-11-23 18:33:13,218 : INFO : sample=0.001 downsamples 51 most-common words
# 2019-11-23 18:33:13,218 : INFO : downsampling leaves estimated 8507828 word corpus (89.6% of prior 9492116)
# 2019-11-23 18:33:13,306 : INFO : estimated required memory for 33167 words and 300 dimensions: 96184300 bytes
# 2019-11-23 18:33:13,307 : INFO : resetting layer weights
# 2019-11-23 18:33:19,596 : INFO : training model with 8 workers on 33167 vocabulary and 300 features, using sg=0 hs=0 sample=0.001 negative=5 window=5
# 2019-11-23 18:33:20,606 : INFO : EPOCH 1 - PROGRESS: at 15.05% examples, 1268691 words/s, in_qsize 15, out_qsize 0
# 2019-11-23 18:33:21,615 : INFO : EPOCH 1 - PROGRESS: at 31.03% examples, 1307941 words/s, in_qsize 5, out_qsize 0
# 2019-11-23 18:33:22,619 : INFO : EPOCH 1 - PROGRESS: at 46.41% examples, 1302027 words/s, in_qsize 1, out_qsize 0
# 2019-11-23 18:33:23,620 : INFO : EPOCH 1 - PROGRESS: at 59.88% examples, 1288252 words/s, in_qsize 11, out_qsize 1
# 2019-11-23 18:33:24,629 : INFO : EPOCH 1 - PROGRESS: at 73.46% examples, 1278336 words/s, in_qsize 14, out_qsize 0
# 2019-11-23 18:33:25,641 : INFO : EPOCH 1 - PROGRESS: at 88.57% examples, 1262991 words/s, in_qsize 11, out_qsize 1
# 2019-11-23 18:33:26,294 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2019-11-23 18:33:26,309 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-11-23 18:33:26,318 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-11-23 18:33:26,319 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-11-23 18:33:26,320 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-11-23 18:33:26,322 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-11-23 18:33:26,332 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-11-23 18:33:26,335 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-11-23 18:33:26,336 : INFO : EPOCH - 1 : training on 9644394 raw words (8506248 effective words) took 6.7s, 1262729 effective words/s
# 2019-11-23 18:33:27,346 : INFO : EPOCH 2 - PROGRESS: at 13.24% examples, 1111642 words/s, in_qsize 2, out_qsize 1
# 2019-11-23 18:33:28,355 : INFO : EPOCH 2 - PROGRESS: at 26.91% examples, 1138728 words/s, in_qsize 0, out_qsize 0
# 2019-11-23 18:33:29,355 : INFO : EPOCH 2 - PROGRESS: at 40.81% examples, 1138462 words/s, in_qsize 13, out_qsize 0
# 2019-11-23 18:33:30,355 : INFO : EPOCH 2 - PROGRESS: at 54.44% examples, 1159493 words/s, in_qsize 0, out_qsize 1
# 2019-11-23 18:33:31,360 : INFO : EPOCH 2 - PROGRESS: at 65.38% examples, 1134439 words/s, in_qsize 0, out_qsize 0
# 2019-11-23 18:33:32,373 : INFO : EPOCH 2 - PROGRESS: at 78.74% examples, 1138271 words/s, in_qsize 15, out_qsize 0
# 2019-11-23 18:33:33,379 : INFO : EPOCH 2 - PROGRESS: at 93.62% examples, 1140186 words/s, in_qsize 7, out_qsize 0
# 2019-11-23 18:33:33,742 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2019-11-23 18:33:33,746 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-11-23 18:33:33,746 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-11-23 18:33:33,755 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-11-23 18:33:33,761 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-11-23 18:33:33,762 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-11-23 18:33:33,770 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-11-23 18:33:33,771 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-11-23 18:33:33,772 : INFO : EPOCH - 2 : training on 9644394 raw words (8507128 effective words) took 7.4s, 1144609 effective words/s
# 2019-11-23 18:33:34,786 : INFO : EPOCH 3 - PROGRESS: at 13.24% examples, 1107912 words/s, in_qsize 15, out_qsize 0
# 2019-11-23 18
words/s, in_qsize 0, out_qsize 0
# 2019-11-23 18:33:55,803 : INFO : EPOCH 5 - PROGRESS: at 92.08% examples, 1123411 words/s, in_qsize 0, out_qsize 1
# 2019-11-23 18:33:56,263 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2019-11-23 18:33:56,266 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-11-23 18:33:56,270 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-11-23 18:33:56,271 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-11-23 18:33:56,278 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-11-23 18:33:56,289 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-11-23 18:33:56,291 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-11-23 18:33:56,292 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-11-23 18:33:56,293 : INFO : EPOCH - 5 : training on 9644394 raw words (8507063 effective words) took 7.5s, 1128073 effective words/s
# 2019-11-23 18:33:56,294 : INFO : training on a 48221970 raw words (42534678 effective words) took 36.7s, 1159048 effective words/s
# 2019-11-23 18:33:56,294 : INFO : saving Word2Vec object under word2vec.model, separately None
# 2019-11-23 18:33:56,296 : INFO : not storing attribute vectors_norm
# 2019-11-23 18:33:56,297 : INFO : not storing attribute cum_table
# 2019-11-23 18:33:57,124 : INFO : saved word2vec.model

# %%
model = Word2Vec.load('word2vec.model')
model.wv.most_similar('本田')
# Out:
# 2019-11-23 19:25:00,699 : INFO : loading Word2Vec object from word2vec.model
# 2019-11-23 19:25:01,182 : INFO : loading wv recursively from word2vec.model.wv.* with mmap=None
# 2019-11-23 19:25:01,182 : INFO : setting ignored attribute vectors_norm to None
# 2019-11-23 19:25:01,183 : INFO : loading vocabulary recursively from word2vec.model.vocabulary.* with mmap=None
# 2019-11-23 19:25:01,184 : INFO : loading trainables recursively from word2vec.model.trainables.* with mmap=None
# 2019-11-23 19:25:01,184 : INFO : setting ignored attribute cum_table to None
# 2019-11-23 19:25:01,185 : INFO : loaded word2vec.model
# 2019-11-23 19:25:01,249 : INFO : precomputing L2-norms of word weight vectors
# [('凌派', 0.7981020212173462),
#  ('crv', 0.7812198400497437),
#  ('缤智', 0.7617830038070679),
#  ('思域', 0.756554901599884),
#  ('十代', 0.7484124898910522),
#  ('东风本田', 0.7482534646987915),
#  ('冠道', 0.7459962964057922),
#  ('广汽', 0.7427908182144165),
#  ('飞度', 0.7418052554130554),
#  ('CRV', 0.7385894060134888)]

# %%
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

line_gen = LineSentence(merger_data_path) # generator，节省内存
model2 = FastText(line_gen, size=300, min_count=5, workers=8)
model2.save('fasttext.model')
# Out:
# 2019-11-23 18:33:57,937 : INFO : resetting layer weights
# 2019-11-23 18:34:28,511 : INFO : collecting all words and their counts
# 2019-11-23 18:34:28,591 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2019-11-23 18:34:28,916 : INFO : PROGRESS: at sentence #10000, processed 932051 words, keeping 37237 word types
# 2019-11-23 18:34:29,211 : INFO : PROGRESS: at sentence #20000, processed 1877470 words, keeping 54830 word types
# 2019-11-23 18:34:29,486 : INFO : PROGRESS: at sentence #30000, processed 2811696 words, keeping 67964 word types
# 2019-11-23 18:34:29,734 : INFO : PROGRESS: at sentence #40000, processed 3718866 words, keeping 79130 word types
words/s, in_qsize 0, out_qsize 0
# 2019-11-23 18:35:49,815 : INFO : EPOCH 5 - PROGRESS: at 46.41% examples, 648376 words/s, in_qsize 14, out_qsize 2
# 2019-11-23 18:35:50,816 : INFO : EPOCH 5 - PROGRESS: at 54.35% examples, 657990 words/s, in_qsize 0, out_qsize 0
# 2019-11-23 18:35:51,817 : INFO : EPOCH 5 - PROGRESS: at 61.04% examples, 656403 words/s, in_qsize 0, out_qsize 0
# 2019-11-23 18:35:52,822 : INFO : EPOCH 5 - PROGRESS: at 68.02% examples, 656921 words/s, in_qsize 0, out_qsize 0
# 2019-11-23 18:35:53,828 : INFO : EPOCH 5 - PROGRESS: at 75.57% examples, 655501 words/s, in_qsize 0, out_qsize 0
# 2019-11-23 18:35:54,851 : INFO : EPOCH 5 - PROGRESS: at 83.97% examples, 654279 words/s, in_qsize 14, out_qsize 1
# 2019-11-23 18:35:55,854 : INFO : EPOCH 5 - PROGRESS: at 92.34% examples, 656067 words/s, in_qsize 0, out_qsize 0
# 2019-11-23 18:35:56,636 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2019-11-23 18:35:56,653 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-11-23 18:35:56,665 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-11-23 18:35:56,681 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-11-23 18:35:56,697 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-11-23 18:35:56,704 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-11-23 18:35:56,705 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-11-23 18:35:56,710 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-11-23 18:35:56,710 : INFO : EPOCH - 5 : training on 9644394 raw words (8506943 effective words) took 13.0s, 656511 effective words/s
# 2019-11-23 18:35:56,711 : INFO : training on a 48221970 raw words (42537133 effective words) took 65.4s, 650145 effective words/s
# 2019-11-23 18:35:57,437 : INFO : saving FastText object under fasttext.model, separately None
# 2019-11-23 18:35:57,439 : INFO : storing np array 'vectors_ngrams' to fasttext.model.wv.vectors_ngrams.npy
# 2019-11-23 18:36:03,948 : INFO : not storing attribute vectors_norm
# 2019-11-23 18:36:03,949 : INFO : not storing attribute vectors_vocab_norm
# 2019-11-23 18:36:03,949 : INFO : not storing attribute vectors_ngrams_norm
# 2019-11-23 18:36:03,949 : INFO : not storing attribute buckets_word
# 2019-11-23 18:36:03,950 : INFO : storing np array 'vectors_ngrams_lockf' to fasttext.model.trainables.vectors_ngrams_lockf.npy
# 2019-11-23 18:36:10,883 : INFO : saved fasttext.model

# %% [markdown]
# ## 3.构建vocab的Embedding Matrix

# %%
vocab = load_file('output/id2word.pkl')
type(vocab)
# Out:
# dict

# %%
embedding_matrix = np.zeros((len(vocab), model.wv.vector_size))
embedding_matrix.shape
# Out:
# (29533, 300)

# %%
vocab = {i-1:x for i,x in vocab.items()}
vocab
# Out:
# {0: '<UNK>',
#  1: '<PAD>',
#  2: '<EOS>',
#  3: '<BOS>',
#  4: '问题',
#  5: '不',
#  6: '没有',
#  7: '好',
#  8: '都',
#  9: '需要',
#  10: '故障',
#  11: '一下',
#  12: '检查',
#  13: '发动机',
#  14: '换',
#  15: '更换',
#  16: '会',
#  17: '正常',
#  18: '车',
#  19: '情况',
#  20: '没',
#  21: '说',
#  22: '机油',
#  23: '去',
#  24: '谢谢',
#  25: '看',
#  26: '电脑',
#  27: '这种',
#  28: '现在',
#  29: '建议',
#  30: '不会',
#  31: '可能',
#  32: '声音',
#  33: '应该',
#  34: '变速箱',
#  35: '清洗',
#  36: '有没有',
#  37: '下',
#  38: '出现',
#  39: '检查一下',
#  40: '上',
#  41: '是否',
#  42: '后',
#  43: '是不是',
#  44: '节气门',
#  45: '影响',
#  46: '不是',
#  47: '启动',
#  48: '还',
#  49: '车子',
#  50: '看看',
#  51: '跑',
#  52: '码',
#  53: '公里',
#  54: '左右',
#  55: '很',
#  56: '大',
#  57: '做',
#  58: '车辆',
#  59: '火花塞',
#  60: '油',
#  61: '师傅',
#  62: '再',
#  63: '请问',
#  64: '位置',
#  65: '传感器',
#  66: '原因',
#  67: '开',
#  68: '年',
#  69: '维修',
#  70: '保养',
#  71: '比较',
#  72: '感觉',
#  73: '行驶',
#  74: '知道',
#  75: '线路',
#  76: '才',
#  77: '里面',
#  78: '时',
#  79: '导致',
#  80: '先',
#  81: '轮胎',
#  82: '4s店',
#  83: '不好',
#  84: '客气',
#  85: '坏',
#  86: '怠速',
#  87: '拆',
#  88: '款',
#  89: '修理厂',
#  90: '不能',
#  91: '使用',
#  92: '电瓶',
#  93: '大师',
#  94: '压力',
#  95: '新',
#  96: '造成',
#  97: '抖动',
#  98: '地方',
#  99: '检测',
#  100: '钥匙',
#  101: '刹车',
#  102: '钱',
#  103: '空调',
#  104: '进行',
#  105: '灯',
#  106: '两个',
#  107: '万公里',
#  108: '显示',
#  109: '熄火',
#  110: '不行',
#  111: '大概',
#  112: '以后',
#  113: '直接',
#  114: '出来',
#  115: '插头',
#  116: '开关',
#  117: '上面',
#  118: '工作',
#  119: '买',
#  120: '解决',
#  121: '匹配',
#  122: '控制',
#  123: '找',
#  124: '加',
#  125: '打开',
#  126: '汽油',
#  127: '档',
#  128: '喷油嘴',
#  129: '缸',
#  130: '高',
#  131: '一点',
#  132: '现象',
#  133: '系统',
#  134: '想',
#  135: '关系',
#  136: '试试',
#  137: '处理',
#  138: '加油',
#  139: '线',
#  140: '肯定',
#  141: '起来',
#  142: '主要',
#  143: '之前',
#  144: '踩',
#  145: '汽车',
#  146: '不用',
#  147: '一次',
#  148: '有点',
#  149: '异响',
#  150: '2',
#  151: '挂',
#  152: '方向盘',
#  153: '具体',
#  154: '损坏',
#  155: '时间',
#  156: '转',
#  157: '怎么回事',
#  158: '之后',
#  159: '图片',
#  160: '不了',
#  161: '东西',
#  162: '螺丝',
#  163: '油耗',
#  164: '问',
#  165: '没事',
#  166: '模块',
#  167: '最好',
#  168: '价格',
#  169: '原厂',
#  170: '1',
#  171: '响',
#  172: '皮带',
#  173: '4S店',
#  174: '只能',
#  175: '亮',
#  176: '积碳',
#  177: '安装',
#  178: '自动',
#  179: '气门',
#  180: '重新',
#  181: '转速',
#  182: '这是',
#  183: '确定',
#  184: '方向',
#  185: '数据',
#  186: '今天',
#  187: '防冻液',
#  188: '描述',
#  189: '信号',
#  190: '咨询',
#  191: '3',
#  192: '高速',
#  193: '保险',
#  194: '仪表',
#  195: '已经',
#  196: '拆下来',
#  197: '发现',
#  198: '点',
#  199: '后面',
#  200: '以前',
#  201: '中',
#  202: '下面',
#  203: '底盘',
#  204: '动力',
#  205: '小',
#  206: '正时',
#  207: '新车',
#  208: '解答',
#  209: '出',
#  210: '这款',
#  211: '修',
#  212: '离合器',
#  213: '测量',
#  214: '不要',
#  215: '4',
#  216: '磨损',
#  217: '冷车',
#  218: '温度',
#  219: '继电器',
#  220: '店',
#  221: '明显',
#  222: '油泵',
#  223: '保险丝',
#  224: '门',
#  225: '外面',
#  226: '水箱',
#  227: '离合',
#  228: '刹车片',
#  229: '电机',
#  230: '意思',
#  231: '明天',
#  232: '点火线圈',
#  233: '水温',
#  234: '油门',
#  235: '读取',
#  236: '不到',
#  237: '氧传感器',
#  238: '点火',
#  239: '电磁阀',
#  240: '电压',
#  241: '风扇',
#  242: '内部',
#  243: '容易',
#  244: '车身',
#  245: '严重',
#  246: '曲轴',
#  247: '质量',
#  248: '漏气',
#  249: '好像',
#  250: '关注',
#  251: '走',
#  252: '导航',
#  253: '前',
#  254: '间隙',
#  255: '凸轮轴',
#  256: '配件',
#  257: '烧',
#  258: '大灯',
#  259: '4s',
#  260: '漏油',
#  261: '引起',
#  262: '里',
#  263: '燃油',
#  264: '加速',
#  265: '10',
#  266: '哒',
#  267: '反应',
#  268: '正',
#  269: '麻烦',
#  270: '特别',
#  271: '才能',
#  272: '5',
#  273: '月',
#  274: '车门',
#  275: '太',
#  276: '完',
#  277: '轴承',
#  278: '分析',
#  279: '听',
#  280: '马达',
#  281: '进气',
#  282: '电子',
#  283: '合成',
#  284: '一定',
#  285: '办法',
#  286: '原车',
#  287: '内',
#  288: '低',
#  289: '起步',
#  290: '电',
#  291: '帮',
#  292: '修复',
#  293: '玻璃',
#  294: '手动',
#  295: '本身',
#  296: '挡',
#  297: '费用',
#  298: '热车',
#  299: '12',
#  300: '空气',
#  301: '请',
#  302: '很多',
#  303: '有时候',
#  304: '车型',
#  305: '必要',
#  306: '随时',
#  307: '前面',
#  308: '刚',
#  309: '发出',
#  310: '车主',
#  311: '三元催化',
#  312: '重点',
#  313: '存在',
#  314: '加装',
#  315: '说明',
#  316: '喷漆',
#  317: '突然',
#  318: '装',
#  319: '号',
#  320: '希望',
#  321: '变速器',
#  322: '防盗',
#  323: '查',
#  324: '属于',
#  325: '看到',
#  326: '助力',
#  327: '数据流',
#  328: '6',
#  329: '链条',
#  330: '无法',
#  331: '调',
#  332: '16',
#  333: '最近',
#  334: '专用',
#  335: '总成',
#  336: '必须',
#  337: '功能',
#  338: '排气管',
#  339: '调整',
#  340: '报',
#  341: '档位',
#  342: '回答',
#  343: '型号',
#  344: '15',
#  345: '下来',
#  346: '变形',
#  347: '连接',
#  348: '考虑',
#  349: '灯亮',
#  350: '压',
#  351: '响声',
#  352: '一会',
#  353: '节温器',
#  354: '弄',
#  355: '方面',
#  356: '减震器',
#  357: '几天',
#  358: '人',
#  359: '效果',
#  360: '刹车油',
#  361: '有时',
#  362: '发电机',
#  363: '调节',
#  364: '全',
#  365: '元',
#  366: '驾驶',
#  367: '速度',
#  368: '关闭',
#  369: '只',
#  370: '判断',
#  371: '报警',
#  372: '注意',
#  373: '提示',
#  374: '四轮定位',
#  375: '堵塞',
#  376: '放',
#  377: '放心',
#  378: '仪表盘',
#  379: '几个',
#  380: '掉',
#  381: '联系',
#  382: '抖',
#  383: '估计',
#  384: '电脑板',
#  385: '最',
#  386: '代码',
#  387: '20',
#  388: '打火',
#  389: '转向',
#  390: '修车',
#  391: '用车',
#  392: '打不着',
#  393: '前轮',
#  394: '早上',
#  395: '开车',
#  396: '大众',
#  397: '压缩机',
#  398: '诊断',
#  399: '固定',
#  400: '品牌',
#  401: '方法',
#  402: '点击',
#  403: '质保',
#  404: '就行了',
#  405: '减震',
#  406: '方向机',
#  407: '打着',
#  408: '停车',
#  409: '觉得',
#  410: '目前',
#  411: '不亮',
#  412: '版',
#  413: '升',
#  414: '很大',
#  415: '网上',
#  416: '到底',
#  417: '噪音',
#  418: '懂',
#  419: '发动',
#  420: '踩油门',
#  421: '那种',
#  422: '大修',
#  423: '头像',
#  424: '购买',
#  425: '单独',
#  426: '暖风',
#  427: '快',
#  428: '找到',
#  429: '试一下',
#  430: '锁',
#  431: '排除',
#  432: '不足',
#  433: '高兴',
#  434: '垫',
#  435: '毛病',
#  436: '测试',
#  437: '复位',
#  438: '明白',
#  439: '洗',
#  440: '长',
#  441: '解码器',
#  442: '倒',
#  443: '火',
#  444: '选择',
#  445: '轻微',
#  446: '一起',
#  447: '设置',
#  448: '13',
#  449: '灯泡',
#  450: '带',
#  451: '状态',
#  452: '滤芯',
#  453: '进去',
#  454: '胎压',
#  455: '清楚',
#  456: '这车',
#  457: '建议您',
#  458: '水温传感器',
#  459: '行车',
#  460: '宝马',
#  461: '排气',
#  462: '差不多',
#  463: '相关',
#  464: '插',
#  465: '倒车',
#  466: '以上',
#  467: '循环',
#  468: '自动挡',
#  469: '顿挫',
#  470: '原来',
#  471: '水',
#  472: '全部',
#  473: '手刹',
#  474: '干净',
#  475: '更',
#  476: '漏',
#  477: '专业',
#  478: '免费',
#  479: '昨天',
#  480: '积炭',
#  481: '不好意思',
#  482: '胶套',
#  483: '定位',
#  484: '异常',
#  485: '球头',
#  486: '中间',
#  487: '帮助',
#  488: '拆开',
#  489: '改装',
#  490: '左',
#  491: '泵',
#  492: '有个',
#  493: '14',
#  494: '基本',
#  495: '换挡',
#  496: '油路',
#  497: '操作',
#  498: '可能性',
#  499: '奥迪',
#  500: '发',
#  501: '松动',
#  502: '愉快',
#  503: '感谢',
#  504: '11',
#  505: '拔',
#  506: '厉害',
#  507: '清除',
#  508: '电源',
#  509: '老化',
#  510: '进',
#  511: '一年',
#  512: '电池',
#  513: '支持',
#  514: '高压',
#  515: '油压',
#  516: '行',
#  517: 'ABS',
#  518: '老师',
#  519: '修理店',
#  520: '度',
#  521: '照片',
#  522: '燃烧',
#  523: '修理',
#  524: '一根',
#  525: '朋友',
#  526: '每次',
#  527: '水泵',
#  528: '接',
#  529: '小时',
#  530: '四个',
#  531: '能够',
#  532: '一段时间',
#  533: '气囊',
#  534: '刚才',
#  535: '就要',
#  536: '部位',
#  537: '厂家',
#  538: '4S',
#  539: '后备箱',
#  540: '后轮',
#  541: '完全',
#  542: '动平衡',
#  543: '缸盖',
#  544: '观察',
#  545: '多久',
#  546: '低速',
#  547: '升级',
#  548: '偶尔',
#  549: '轮毂',
#  550: '停',
#  551: '万',
#  552: '继续',
#  553: '当时',
#  554: '右',
#  555: '图',
#  556: '过程',
#  557: '三个',
#  558: '贵',
#  559: '少',
#  560: '车速',
#  561: '遥控器',
#  562: '动',
#  563: '拍',
#  564: '喇叭',
#  565: '部件',
#  566: '100',
#  567: '油箱',
#  568: '不同',
#  569: '2000',
#  570: '偏',
#  571: '半轴',
#  572: '断',
#  573: '听到',
#  574: '30',
#  575: '喷',
#  576: '换个',
#  577: '技师',
#  578: '不够',
#  579: '之间',
#  580: '没什么',
#  581: '气缸',
#  582: '改',
#  583: '担心',
#  584: '碳',
#  585: '进入',
#  586: '刚刚',
#  587: '量',
#  588: '经常',
#  589: '喷油',
#  590: '刹车盘',
#  591: '试',
#  592: '拆掉',
#  593: '超过',
#  594: '清理',
#  595: '数',
#  596: '推荐',
#  597: '变化',
#  598: '遥控',
#  599: '产生',
#  600: '后来',
#  601: '及时',
#  602: '学习',
#  603: '拉',
#  604: '断电',
#  605: '确认',
#  606: '要求',
#  607: '谢谢您',
#  608: '颜色',
#  609: '7',
#  610: '试车',
#  611: '非常',
#  612: '主',
#  613: '轮',
#  614: '热',
#  615: '怕',
#  616: '车上',
#  617: '测',
#  618: '排量',
#  619: '不错',
#  620: '线束',
#  621: '解决问题',
#  622: '电路',
#  623: '牌子',
#  624: '怀疑',
#  625: '不响',
#  626: '遇到',
#  627: '8',
#  628: '大约',
#  629: '手动挡',
#  630: '盖',
#  631: '右边',
#  632: '上次',
#  633: '添加',
#  634: '95',
#  635: '提速',
#  636: '平时',
#  637: '拔掉',
#  638: '嘉实多',
#  639: '几次',
#  640: '短路',
#  641: '路',
#  642: '包括',
#  643: '钣金',
#  644: '确实',
#  645: '读',
#  646: '是因为',
#  647: '作用',
#  648: '修好',
#  649: '座椅',
#  650: '半',
#  651: '帮到',
#  652: '稳定',
#  653: '安全',
#  654: '电阻',
#  655: '转动',
#  656: '店里',
#  657: '堵',
#  658: '美孚',
#  659: '无',
#  660: '失火',
#  661: '拉杆',
#  662: '最后',
#  663: '机',
#  664: '机滤',
#  665: '松',
#  666: '祝您',
#  667: '排',
#  668: '按键',
#  669: '稍微',
#  670: '天窗',
#  671: '供电',
#  672: '单元',
#  673: '程序',
#  674: '还要',
#  675: '3000',
#  676: '高温',
#  677: '左边',
#  678: '09',
#  679: '负极',
#  680: '四',
#  681: '检修',
#  682: '所有',
#  683: '发生',
#  684: '急',
#  685: '水管',
#  686: '冬天',
#  687: '性能',
#  688: '气阀',
#  689: '刚换',
#  690: '废',
#  691: '没用',
#  692: '汽油泵',
#  693: '上去',
#  694: '臂',
#  695: '17',
#  696: 'D',
#  697: '齿轮',
#  698: '就行',
#  699: '过来',
#  700: '没换',
#  701: '副',
#  702: '进气道',
#  703: '搞',
#  704: '增加',
#  705: '电话',
#  706: '模式',
#  707: '便宜',
#  708: '没电',
#  709: '记号',
#  710: '按钮',
#  711: '来说',
#  712: '鼓风机',
#  713: '200',
#  714: '漆',
#  715: '事',
#  716: '润滑',
#  717: '里程',
#  718: '拆卸',
#  719: '1000',
#  720: '告诉',
#  721: '慢慢',
#  722: '声',
#  723: '40',
#  724: '当地',
#  725: '挂挡',
#  726: '管子',
#  727: '下降',
#  728: '不用谢',
#  729: '进气管',
#  730: '5000',
#  731: 'abs',
#  732: '丰田',
#  733: '撞',
#  734: '接触',
#  735: '漏水',
#  736: '事故',
#  737: '合适',
#  738: '回复',
#  739: '消失',
#  740: '悬挂',
#  741: '方便',
#  742: '后期',
#  743: '混合气',
#  744: '分钟',
#  745: '两根',
#  746: '副驾驶',
#  747: '密封',
#  748: '求',
#  749: '整个',
#  750: '卖',
#  751: '涡轮',
#  752: '达到',
#  753: '开着',
#  754: '起动',
#  755: '点火开关',
#  756: '顶',
#  757: '原地',
#  758: '图文',
#  759: '别克',
#  760: '老',
#  761: '工具',
#  762: '机械',
#  763: '打滑',
#  764: '回',
#  765: '脏',
#  766: '摩擦',
#  767: '进水',
#  768: '冷却液',
#  769: '油封',
#  770: '挺',
#  771: '起动机',
#  772: '奔驰',
#  773: '阀',
#  774: '三元催化器',
#  775: '阀体',
#  776: '一键',
#  777: '18',
#  778: '回来',
#  779: '搭',
#  780: '简单',
#  781: '无力',
#  782: '助力泵',
#  783: '到位',
#  784: '专用工具',
#  785: '缺缸',
#  786: '晚上',
#  787: '卡',
#  788: '好好',
#  789: '震动',
#  790: '天气',
#  791: '粘度',
#  792: '空挡',
#  793: '跳',
#  794: '一对一',
#  795: '300',
#  796: '吹',
#  797: '冷',
#  798: '请教',
#  799: '油门踏板',
#  800: '一体',
#  801: '找个',
#  802: '二手车',
#  803: '手机',
#  804: '升降',
#  805: '92',
#  806: '盖子',
#  807: '一种',
#  808: '接触不良',
#  809: '黑色',
#  810: '保险杠',
#  811: '两',
#  812: '保险盒',
#  813: '运转',
#  814: '燃烧室',
#  815: '问问',
#  816: '差',
#  817: '双',
#  818: '更好',
#  819: '室盖',
#  820: '涡轮增压',
#  821: '范围',
#  822: '打不开',
#  823: '一缸',
#  824: '共振',
#  825: '80',
#  826: '盒',
#  827: '普通',
#  828: '个人',
#  829: '塑料',
#  830: '慢',
#  831: '提供',
#  832: '一块',
#  833: '码是',
#  834: '拆装',
#  835: '充电',
#  836: '我车',
#  837: '护板',
#  838: '空滤',
#  839: '漏电',
#  840: '保修',
#  841: '旁边',
#  842: '机器',
#  843: '轮子',
#  844: '路面',
#  845: '基本上',
#  846: '视频',
#  847: '标准',
#  848: '清洗剂',
#  849: '设备',
#  850: '感',
#  851: '08',
#  852: '没关系',
#  853: '附近',
#  854: '准确',
#  855: '即可',
#  856: '中控',
#  857: '要换',
#  858: '马上',
#  859: '弹簧',
#  860: '真的',
#  861: '油底壳',
#  862: '样子',
#  863: '两年',
#  864: '块钱',
#  865: '技术',
#  866: '生锈',
#  867: '首保',
#  868: '原装',
#  869: '三',
#  870: '提问',
#  871: '真空',
#  872: '消除',
#  873: '部分',
#  874: '彻底',
#  875: '松开',
#  876: '灯不亮',
#  877: '下次',
#  878: '区别',
#  879: '一档',
#  880: '编程',
#  881: '通电',
#  882: '实际',
#  883: '两次',
#  884: '平衡杆',
#  885: '雨刮',
#  886: '好点',
#  887: '关键',
#  888: '指示灯',
#  889: '器',
#  890: '500',
#  891: '过大',
#  892: '驾驶室',
#  893: '本田',
#  894: '老款',
#  895: '不良',
#  896: '支架',
#  897: '一点点',
#  898: '当然',
#  899: '对车',
#  900: '恩',
#  901: '别人',
#  902: '大神',
#  903: '蓄电池',
#  904: '索赔',
#  905: '一声',
#  906: '空调滤芯',
#  907: '两天',
#  908: '软件',
#  909: '科鲁兹',
#  910: '越',
#  911: '帮忙',
#  912: '路上',
#  913: '打铁',
#  914: '第一次',
#  915: '换掉',
#  916: '拉线',
#  917: '左侧',
#  918: '多公里',
#  919: '已',
#  920: '开启',
#  921: '电路图',
#  922: '换油',
#  923: '件',
#  924: '发动机舱',
#  925: '厂',
#  926: '管路',
#  927: '每个',
#  928: '右侧',
#  929: '半年',
#  930: '散热',
#  931: '不大',
#  932: '灯亮了',
#  933: '灯光',
#  934: '类似',
#  935: '速腾',
#  936: '60',
#  937: '来看',
#  938: '指点',
#  939: '问下',
#  940: '缺少',
#  941: '万用表',
#  942: '主机',
#  943: '120',
#  944: '三件套',
#  945: '标志',
#  946: '降低',
#  947: '信息',
#  948: '做个',
#  949: '够不够',
#  950: '下去',
#  951: '波箱',
#  952: '卡住',
#  953: '液压',
#  954: '工时费',
#  955: '正确',
#  956: '仪表台',
#  957: '刮',
#  958: '好多',
#  959: 's',
#  960: '',
#  961: '800',
#  962: '秒',
#  963: '亲',
#  964: '平台',
#  965: '断开',
#  966: '孔',
#  967: '长时间',
#  968: '对比',
#  969: '万多公里',
#  970: '水壶',
#  971: '车轮',
#  972: '柴油',
#  973: '暂时',
#  974: '比亚迪',
#  975: '离合器片',
#  976: '重',
#  977: '长安',
#  978: '过去',
#  979: '三年',
#  980: '后视镜',
#  981: '有电',
#  982: '抬',
#  983: '一边',
#  984: '零件',
#  985: '第一',
#  986: '伏',
#  987: '外',
#  988: '配置',
#  989: '以为',
#  990: '显示屏',
#  991: '1500',
#  992: '上来',
#  993: '人员',
#  994: '位',
#  995: '不稳',
#  996: '解锁',
#  997: '增压器',
#  998: '换过',
#  999: '收音机',
#  ...}

# %%
for i,w in vocab.items():
    embedding_matrix[i] =

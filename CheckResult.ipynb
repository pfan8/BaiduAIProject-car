# %%
import pickle
with open('output/test/word2id.pkl', 'rb') as f:
    word2id = pickle.load(f)
len(word2id)
# Out:
# 49296

# %%
word2id
# Out:
# {'<UNK>': 1,
#  '<PAD>': 2,
#  '<EOS>': 3,
#  '<BOS>': 4,
#  '说': 5,
#  '，': 6,
#  '：': 7,
#  '|': 8,
#  '的': 9,
#  '技师': 10,
#  '车主': 11,
#  '了': 12,
#  '。': 13,
#  '是': 14,
#  '？': 15,
#  '我': 16,
#  '有': 17,
#  '你': 18,
#  '可以': 19,
#  '就': 20,
#  '不': 21,
#  '问题': 22,
#  '吗': 23,
#  '这个': 24,
#  '没有': 25,
#  '在': 26,
#  '！': 27,
#  '好': 28,
#  '也': 29,
#  '都': 30,
#  '什么': 31,
#  '你好': 32,
#  '换': 33,
#  '就是': 34,
#  '需要': 35,
#  '会': 36,
#  '一下': 37,
#  '故障': 38,
#  '发动机': 39,
#  '更换': 40,
#  '检查': 41,
#  '如果': 42,
#  '谢谢': 43,
#  '车': 44,
#  '对': 45,
#  '那': 46,
#  '和': 47,
#  '没': 48,
#  '正常': 49,
#  '用': 50,
#  '机油': 51,
#  '吧': 52,
#  '去': 53,
#  '还是': 54,
#  '到': 55,
#  '您': 56,
#  '的话': 57,
#  '一个': 58,
#  '要': 59,
#  '现在': 60,
#  '情况': 61,
#  '能': 62,
#  '把': 63,
#  '时候': 64,
#  '看': 65,
#  '还有': 66,
#  '这': 67,
#  '嗯': 68,
#  '怎么': 69,
#  '不会': 70,
#  '这样': 71,
#  '啊': 72,
#  '过': 73,
#  '可能': 74,
#  '电脑': 75,
#  '多少': 76,
#  '下': 77,
#  '声音': 78,
#  '有没有': 79,
# ...
